# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
import pandas as pd

df = pd.read_csv(r"C:\Users\Lachy\Documents\PlatformIO\Projects\Metric Prototype\Curl_Detection_Dataset.csv")

feature_cols = ["acc_std", "acc_range", "gyro_std", "gyro_mean", "ay_std"]
X = df[feature_cols]
y = df["label"]

Xtr, Xte, ytr, yte = train_test_split(X, y, test_size=0.3)
seg_model = RandomForestClassifier()
seg_model.fit(Xtr, ytr)
print("Segmentation accuracy:", seg_model.score(Xte, yte))


preds = seg_model.predict(Xte)
print(confusion_matrix(yte, preds))
print(classification_report(yte, preds))
# Out:
# Segmentation accuracy: 0.8159806295399515
# [[220  27]
#  [ 49 117]]
#               precision    recall  f1-score   support
#
#        curls       0.82      0.89      0.85       247
#        noise       0.81      0.70      0.75       166
#
#     accuracy                           0.82       413
#    macro avg       0.82      0.80      0.80       413
# weighted avg       0.82      0.82      0.81       413
